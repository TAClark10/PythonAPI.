# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime as dt
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 644

# %%
for i, city in enumerate(cities):
    print(i, city)
# Out:
# 0 caravelas
# 1 yenagoa
# 2 provideniya
# 3 bredasdorp
# 4 puerto ayora
# 5 warqla
# 6 mataura
# 7 manggar
# 8 castro
# 9 maldonado
# 10 kodiak
# 11 russkaya polyana
# 12 hilo
# 13 tura
# 14 arraial do cabo
# 15 punta arenas
# 16 busselton
# 17 longyearbyen
# 18 harper
# 19 jaguaribe
# 20 batagay-alyta
# 21 mount isa
# 22 zhanatas
# 23 hobart
# 24 kosonsoy
# 25 port elizabeth
# 26 north platte
# 27 albany
# 28 saint george
# 29 lebu
# 30 akdepe
# 31 sayyan
# 32 cabo san lucas
# 33 mayumba
# 34 polur
# 35 kawana waters
# 36 ixtapa
# 37 cape town
# 38 airai
# 39 pandan
# 40 saldanha
# 41 laurel
# 42 te anau
# 43 vaini
# 44 poum
# 45 tuktoyaktuk
# 46 vahan
# 47 formoso do araguaia
# 48 ushuaia
# 49 nantucket
# 50 natal
# 51 sur
# 52 hamilton
# 53 maghama
# 54 shush
# 55 portland
# 56 bar harbor
# 57 novorzhev
# 58 narsaq
# 59 salcininkai
# 60 sitka
# 61 forbes
# 62 monrovia
# 63 torbay
# 64 taraz
# 65 ostrovnoy
# 66 koplik
# 67 thasra
# 68 jamestown
# 69 maykain
# 70 sharjah
# 71 sentyabrskiy
# 72 taolanaro
# 73 adana
# 74 hithadhoo
# 75 fairbanks
# 76 honiara
# 77 qaqortoq
# 78 itaituba
# 79 vaitupu
# 80 rikitea
# 81 sobolevo
# 82 krasnyy chikoy
# 83 saint-augustin
# 84 guelengdeng
# 85 carinhanha
# 86 bambous virieux
# 87 jamsa
# 88 paamiut
# 89 dzhusaly
# 90 butaritari
# 91 barrow
# 92 acarau
# 93 carballo
# 94 san quintin
# 95 camacari
# 96 taoudenni
# 97 sinnar
# 98 college
# 99 bluff
# 100 mahebourg
# 101 padang
# 102 nova olimpia
# 103 east london
# 104 newburgh
# 105 cherskiy
# 106 faanui
# 107 qaanaaq
# 108 san cristobal
# 109 nyaunglebin
# 110 nizhneyansk
# 111 ngama
# 112 kahta
# 113 vanavara
# 114 belushya guba
# 115 constitucion
# 116 rocha
# 117 dawson creek
# 118 waipawa
# 119 ingham
# 120 namibe
# 121 dembi dolo
# 122 houma
# 123 brae
# 124 hofn
# 125 muisne
# 126 sarangani
# 127 berdigestyakh
# 128 luderitz
# 129 inhambane
# 130 bata
# 131 miri
# 132 saskylakh
# 133 prince george
# 134 kapaa
# 135 mugur-aksy
# 136 buchanan
# 137 illoqqortoormiut
# 138 carnarvon
# 139 kahului
# 140 ponta delgada
# 141 palabuhanratu
# 142 upernavik
# 143 ribeira grande
# 144 dakar
# 145 victoria
# 146 gorontalo
# 147 belokurikha
# 148 nanortalik
# 149 atuona
# 150 aklavik
# 151 avarua
# 152 mullaitivu
# 153 tasiilaq
# 154 lorengau
# 155 samusu
# 156 zhigansk
# 157 unguras
# 158 mar del plata
# 159 tabou
# 160 chokurdakh
# 161 sao filipe
# 162 virginia beach
# 163 yulara
# 164 ponta do sol
# 165 cotonou
# 166 teguldet
# 167 port alfred
# 168 hermanus
# 169 areia branca
# 170 ayan
# 171 norman wells
# 172 beringovskiy
# 173 port-gentil
# 174 georgetown
# 175 raudeberg
# 176 payo
# 177 cravo norte
# 178 kuala krai
# 179 angoram
# 180 labuhan
# 181 saint pete beach
# 182 mango
# 183 murdochville
# 184 lompoc
# 185 yellowknife
# 186 vao
# 187 cayenne
# 188 san patricio
# 189 lagoa
# 190 shache
# 191 leningradskiy
# 192 kaeo
# 193 klaksvik
# 194 tarudant
# 195 the pas
# 196 tsihombe
# 197 plettenberg bay
# 198 pevek
# 199 bahia honda
# 200 islamkot
# 201 salo
# 202 coahuayana
# 203 melendugno
# 204 new norfolk
# 205 giyani
# 206 mys shmidta
# 207 muravlenko
# 208 kitimat
# 209 kamenskoye
# 210 dingle
# 211 esperance
# 212 nome
# 213 katsuura
# 214 axim
# 215 nata
# 216 great yarmouth
# 217 lieksa
# 218 lugovskiy
# 219 westport
# 220 bonavista
# 221 solnechnyy
# 222 uvarovo
# 223 gamboma
# 224 taburi
# 225 jijiang
# 226 aksarka
# 227 chuy
# 228 pringsewu
# 229 whitehorse
# 230 alofi
# 231 severo-kurilsk
# 232 hualmay
# 233 pisco
# 234 clyde river
# 235 lavrentiya
# 236 boa vista
# 237 flinders
# 238 srandakan
# 239 paradwip
# 240 carutapera
# 241 bilibino
# 242 khasan
# 243 piyi
# 244 barentsburg
# 245 pangnirtung
# 246 riyadh
# 247 husavik
# 248 turbat
# 249 sao joao da barra
# 250 havoysund
# 251 gonbad-e qabus
# 252 sola
# 253 artyk
# 254 skalistyy
# 255 cam ranh
# 256 rio grande
# 257 flin flon
# 258 carauari
# 259 nichinan
# 260 pijino
# 261 manhush
# 262 pemba
# 263 mareeba
# 264 lubango
# 265 sabang
# 266 andenes
# 267 fortuna
# 268 havelock
# 269 merauke
# 270 santa rosa
# 271 cap-aux-meules
# 272 naze
# 273 yar-sale
# 274 aviles
# 275 thompson
# 276 urumqi
# 277 brahmapuri
# 278 saint-philippe
# 279 touros
# 280 morgan city
# 281 yeniseysk
# 282 sal rei
# 283 kavieng
# 284 bethel
# 285 ruatoria
# 286 codrington
# 287 richards bay
# 288 oromocto
# 289 saint anthony
# 290 fayetteville
# 291 amderma
# 292 praya
# 293 mbanza-ngungu
# 294 port hedland
# 295 sioux lookout
# 296 bela
# 297 antofagasta
# 298 songjianghe
# 299 satitoa
# 300 tumannyy
# 301 altamira
# 302 noumea
# 303 yumen
# 304 dikson
# 305 goderich
# 306 alice springs
# 307 cap malheureux
# 308 bathsheba
# 309 warri
# 310 isangel
# 311 borzya
# 312 mulege
# 313 palmer
# 314 bethanien
# 315 cacequi
# 316 talnakh
# 317 tiksi
# 318 tornio
# 319 abu dhabi
# 320 tessalit
# 321 kindu
# 322 kruisfontein
# 323 kayes
# 324 havre-saint-pierre
# 325 cidreira
# 326 puerto escondido
# 327 stornoway
# 328 el triunfo
# 329 rio gallegos
# 330 olavarria
# 331 puerto colombia
# 332 quzhou
# 333 karauzyak
# 334 makakilo city
# 335 lodja
# 336 swan hill
# 337 coihaique
# 338 truro
# 339 barawe
# 340 north bend
# 341 bubaque
# 342 bairiki
# 343 atbasar
# 344 twentynine palms
# 345 kourou
# 346 brindisi
# 347 balkhash
# 348 knyaze-volkonskoye
# 349 grindavik
# 350 olenegorsk
# 351 ucluelet
# 352 pampas
# 353 adrar
# 354 guerrero negro
# 355 grand river south east
# 356 coquimbo
# 357 ahualulco
# 358 tamandare
# 359 chameza
# 360 bolshaya rechka
# 361 durango
# 362 hay river
# 363 buala
# 364 krasnoselkup
# 365 strezhevoy
# 366 khatanga
# 367 killybegs
# 368 caconda
# 369 attawapiskat
# 370 churapcha
# 371 vestmannaeyjar
# 372 kamiiso
# 373 roebourne
# 374 longyan
# 375 santa luzia
# 376 olafsvik
# 377 champerico
# 378 nikolskoye
# 379 bereda
# 380 west bay
# 381 sharkan
# 382 la asuncion
# 383 kirkland lake
# 384 lingsugur
# 385 jacareacanga
# 386 hammerfest
# 387 geraldton
# 388 braslav
# 389 dzaoudzi
# 390 itacarambi
# 391 homer
# 392 henties bay
# 393 metro
# 394 grand-lahou
# 395 channel-port aux basques
# 396 marawi
# 397 ahipara
# 398 hwange
# 399 gonen
# 400 luena
# 401 zhezkazgan
# 402 lipin bor
# 403 dudinka
# 404 garowe
# 405 kibaya
# 406 shirvan
# 407 evensk
# 408 aflu
# 409 deloraine
# 410 lincoln
# 411 najran
# 412 castelfiorentino
# 413 gazimurskiy zavod
# 414 maxixe
# 415 oum hadjer
# 416 teutonia
# 417 nokaneng
# 418 beloha
# 419 caluquembe
# 420 okulovka
# 421 buzmeyin
# 422 kavaratti
# 423 tabialan
# 424 mackenzie
# 425 shenzhen
# 426 baykit
# 427 hambantota
# 428 wajir
# 429 asau
# 430 muyezerskiy
# 431 bomi
# 432 igarka
# 433 skibbereen
# 434 tabiauea
# 435 tsabong
# 436 meadow lake
# 437 ilulissat
# 438 kuche
# 439 katima mulilo
# 440 mungwi
# 441 mount gambier
# 442 santa maria
# 443 nyimba
# 444 denpasar
# 445 prudentopolis
# 446 rapid city
# 447 caraballeda
# 448 rosarito
# 449 broken hill
# 450 saleaula
# 451 navrongo
# 452 joutseno
# 453 ruteng
# 454 praia
# 455 ust-bolsheretsk
# 456 laguna
# 457 marigot
# 458 chumikan
# 459 cabedelo
# 460 may pen
# 461 ambato
# 462 chillan
# 463 estelle
# 464 malwan
# 465 ancud
# 466 lasa
# 467 mehamn
# 468 sohag
# 469 aykhal
# 470 kimbe
# 471 orgun
# 472 vardo
# 473 parkes
# 474 port shepstone
# 475 marienburg
# 476 pachino
# 477 manama
# 478 robertsport
# 479 danielskuil
# 480 funadhoo
# 481 tarbes
# 482 matagami
# 483 harnosand
# 484 shiyan
# 485 souillac
# 486 vila velha
# 487 kingsland
# 488 taltal
# 489 korla
# 490 kabalo
# 491 panguna
# 492 liverpool
# 493 acapulco
# 494 walvis bay
# 495 galveston
# 496 armacao dos buzios
# 497 xinyu
# 498 guiyang
# 499 muros
# 500 upington
# 501 hasaki
# 502 samarai
# 503 kurumkan
# 504 young
# 505 andevoranto
# 506 halalo
# 507 iqaluit
# 508 nouadhibou
# 509 okha
# 510 tarko-sale
# 511 srednekolymsk
# 512 saint-joseph
# 513 bonthe
# 514 bangassou
# 515 ampanihy
# 516 barbar
# 517 atar
# 518 daloa
# 519 pangody
# 520 zhangjiakou
# 521 guilin
# 522 kijang
# 523 hohhot
# 524 yushala
# 525 dalton
# 526 ouesso
# 527 trinidad
# 528 sapouy
# 529 lahaina
# 530 neuquen
# 531 puerto madryn
# 532 benin
# 533 fergus falls
# 534 minot
# 535 san lawrenz
# 536 iquique
# 537 ozinki
# 538 puerto narino
# 539 takoradi
# 540 phra phutthabat
# 541 tautira
# 542 arona
# 543 haukipudas
# 544 charters towers
# 545 labutta
# 546 khovu-aksy
# 547 vicuna
# 548 quatre cocos
# 549 wahiawa
# 550 virovitica
# 551 chimbote
# 552 talladega
# 553 port macquarie
# 554 turayf
# 555 bangui
# 556 la ronge
# 557 mlowo
# 558 andra
# 559 la tuque
# 560 maan
# 561 ende
# 562 rudnogorsk
# 563 methala
# 564 stettler
# 565 bolungarvik
# 566 mirnyy
# 567 cumberland
# 568 along
# 569 cuamba
# 570 san pedro
# 571 chastyye
# 572 tabas
# 573 pasighat
# 574 pierre
# 575 vallenar
# 576 kribi
# 577 petropavlovsk-kamchatskiy
# 578 oyama
# 579 aripuana
# 580 sao sebastiao
# 581 penzance
# 582 lichtenburg
# 583 fare
# 584 broome
# 585 mocorito
# 586 launceston
# 587 saint-pierre
# 588 marcona
# 589 nenjiang
# 590 bonnyville
# 591 karratha
# 592 mrirt
# 593 kuruman
# 594 omboue
# 595 beira
# 596 bengkulu
# 597 dzilam gonzalez
# 598 camacha
# 599 mankono
# 600 banmo
# 601 matara
# 602 bridlington
# 603 kikwit
# 604 khirkiya
# 605 dicabisagan
# 606 mwanza
# 607 berezovyy
# 608 pinega
# 609 yugo-kamskiy
# 610 pyaozerskiy
# 611 ushi
# 612 vreed en hoop
# 613 verkhovye
# 614 kununurra
# 615 yanam
# 616 ye
# 617 dire dawa
# 618 tanete
# 619 catamayo
# 620 ugoofaaru
# 621 kutum
# 622 san roque
# 623 ust-kulom
# 624 maragheh
# 625 fasa
# 626 moroni
# 627 salalah
# 628 macusani
# 629 tete
# 630 fort saint james
# 631 athabasca
# 632 fort stewart
# 633 diffa
# 634 balimo
# 635 novobirilyussy
# 636 kirkwall
# 637 meyungs
# 638 huarmey
# 639 gat
# 640 marsabit
# 641 katherine
# 642 the valley
# 643 anadyr

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#base url
#url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=(weather_api_key)&q=" #+ city
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#list of city data
cityname=[]
Lat = []
Long = []
temp = []
Humidity = []
Clouds = []
Speed = []
Date = [ ]
#grouping variables
set_count =1 # group
record = 1 # record within the group

print ("Beginning Data Retrieval")
print("-----------------------")
      
for i, city in enumerate(cities):
    #group the cities in sets of 50
    if(i % 50 == 0 and i >= 50):
        set_count += 1 # make a new group
        record = 0 #reset the count of records in the new group
      
    # outpout the record and group and name of the city being processed from the list of cities
    #print(f"Processing Record {record} of Set {set_count} | {city}")
    
    #increase the record count within the set
   
   
    # create a url that includes the city
    cityURL = query_url + city
    
    # call the openweather API and make a request
    try:
        
        cityweather = requests.get(cityURL).json()
        #print(cityweather)
        
        lat = cityweather["coord"]["lat"]
        #print(lat)
        lng = cityweather["coord"]["lon"]
        #print(lng)
        maxtem = cityweather["main"]["temp_max"]
        #print(maxtem)
        humidity = cityweather["main"]["humidity"]
        #print(humidity)
        cloudiness = cityweather["clouds"]["all"]
        #print(cloudiness)
        windspeed = cityweather["wind"]["speed"]
        #print(windspeed)
        date = cityweather["dt"]
        #print(date)
       
        cityname.append(city)
        
        Lat.append(lat)
       
        Long.append(lng)
       
        temp.append(maxtem)
        
        Humidity.append(humidity)
       
        Speed.append(windspeed)
        
        Clouds.append(cloudiness)
       
        Date.append(date)
       
        print(f"Processing Record {record} of Set {set_count} | {city}") 
        record+=1
        
    except:
        print(f"{city} not found. Skipping....")
# Out:
# Beginning Data Retrieval
# -----------------------
# Processing Record 1 of Set 1 | caravelas
# Processing Record 2 of Set 1 | yenagoa
# Processing Record 3 of Set 1 | provideniya
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | puerto ayora
# warqla not found. Skipping....
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | manggar
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | maldonado
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | russkaya polyana
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | tura
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | harper
# Processing Record 19 of Set 1 | jaguaribe
# Processing Record 20 of Set 1 | batagay-alyta
# Processing Record 21 of Set 1 | mount isa
# zhanatas not found. Skipping....
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | kosonsoy
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | north platte
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | lebu
# Processing Record 29 of Set 1 | akdepe
# Processing Record 30 of Set 1 | sayyan
# Processing Record 31 of Set 1 | cabo san lucas
# Processing Record 32 of Set 1 | mayumba
# Processing Record 33 of Set 1 | polur
# kawana waters not found. Skipping....
# Processing Record 34 of Set 1 | ixtapa
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | airai
# Processing Record 37 of Set 1 | pandan
# Processing Record 38 of Set 1 | saldanha
# Processing Record 39 of Set 1 | laurel
# Processing Record 40 of Set 1 | te anau
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | poum
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | vahan
# formoso do araguaia not found. Skipping....
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | nantucket
# Processing Record 0 of Set 2 | natal
# Processing Record 1 of Set 2 | sur
# Processing Record 2 of Set 2 | hamilton
# maghama not found. Skipping....
# Processing Record 3 of Set 2 | shush
# Processing Record 4 of Set 2 | portland
# Processing Record 5 of Set 2 | bar harbor
# Processing Record 6 of Set 2 | novorzhev
# Processing Record 7 of Set 2 | narsaq
# Processing Record 8 of Set 2 | salcininkai
# Processing Record 9 of Set 2 | sitka
# Processing Record 10 of Set 2 | forbes
# Processing Record 11 of Set 2 | monrovia
# Processing Record 12 of Set 2 | torbay
# Processing Record 13 of Set 2 | taraz
# Processing Record 14 of Set 2 | ostrovnoy
# Processing Record 15 of Set 2 | koplik
# Processing Record 16 of Set 2 | thasra
# Processing Record 17 of Set 2 | jamestown
# maykain not found. Skipping....
# Processing Record 18 of Set 2 | sharjah
# sentyabrskiy not found. Skipping....
# taolanaro not found. Skipping....
# Processing Record 19 of Set 2 | adana
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | fairbanks
# Processing Record 22 of Set 2 | honiara
# Processing Record 23 of Set 2 | qaqortoq
# Processing Record 24 of Set 2 | itaituba
# vaitupu not found. Skipping....
# Processing Record 25 of Set 2 | rikitea
# Processing Record 26 of Set 2 | sobolevo
# Processing Record 27 of Set 2 | krasnyy chikoy
# Processing Record 28 of Set 2 | saint-augustin
# guelengdeng not found. Skipping....
# Processing Record 29 of Set 2 | carinhanha
# Processing Record 30 of Set 2 | bambous virieux
# Processing Record 31 of Set 2 | jamsa
# Processing Record 32 of Set 2 | paamiut
# dzhusaly not found. Skipping....
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | acarau
# Processing Record 36 of Set 2 | carballo
# Processing Record 37 of Set 2 | san quintin
# Processing Record 38 of Set 2 | camacari
# Processing Record 39 of Set 2 | taoudenni
# Processing Record 40 of Set 2 | sinnar
# Processing Record 41 of Set 2 | college
# Processing Record 42 of Set 2 | bluff
# Processing Record 0 of Set 3 | mahebourg
# Processing Record 1 of Set 3 | padang
# Processing Record 2 of Set 3 | nova olimpia
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | newburgh
# Processing Record 5 of Set 3 | cherskiy
# Processing Record 6 of Set 3 | faanui
# Processing Record 7 of Set 3 | qaanaaq
# Processing Record 8 of Set 3 | san cristobal
# Processing Record 9 of Set 3 | nyaunglebin
# nizhneyansk not found. Skipping....
# Processing Record 10 of Set 3 | ngama
# Processing Record 11 of Set 3 | kahta
# Processing Record 12 of Set 3 | vanavara
# belushya guba not found. Skipping....
# Processing Record 13 of Set 3 | constitucion
# Processing Record 14 of Set 3 | rocha
# Processing Record 15 of Set 3 | dawson creek
# Processing Record 16 of Set 3 | waipawa
# Processing Record 17 of Set 3 | ingham
# Processing Record 18 of Set 3 | namibe
# Processing Record 19 of Set 3 | dembi dolo
# Processing Record 20 of Set 3 | houma
# Processing Record 21 of Set 3 | brae
# Processing Record 22 of Set 3 | hofn
# Processing Record 23 of Set 3 | muisne
# Processing Record 24 of Set 3 | sarangani
# Processing Record 25 of Set 3 | berdigestyakh
# Processing Record 26 of Set 3 | luderitz
# Processing Record 27 of Set 3 | inhambane
# Processing Record 28 of Set 3 | bata
# Processing Record 29 of Set 3 | miri
# Processing Record 30 of Set 3 | saskylakh
# Processing Record 31 of Set 3 | prince george
# Processing Record 32 of Set 3 | kapaa
# Processing Record 33 of Set 3 | mugur-aksy
# Processing Record 34 of Set 3 | buchanan
# illoqqortoormiut not found. Skipping....
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | kahului
# Processing Record 37 of Set 3 | ponta delgada
# palabuhanratu not found. Skipping....
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | ribeira grande
# Processing Record 40 of Set 3 | dakar
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | gorontalo
# Processing Record 43 of Set 3 | belokurikha
# Processing Record 44 of Set 3 | nanortalik
# Processing Record 45 of Set 3 | atuona
# Processing Record 0 of Set 4 | aklavik
# Processing Record 1 of Set 4 | avarua
# mullaitivu not found. Skipping....
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | lorengau
# samusu not found. Skipping....
# Processing Record 4 of Set 4 | zhigansk
# Processing Record 5 of Set 4 | unguras
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | tabou
# Processing Record 8 of Set 4 | chokurdakh
# Processing Record 9 of Set 4 | sao filipe
# Processing Record 10 of Set 4 | virginia beach
# Processing Record 11 of Set 4 | yulara
# Processing Record 12 of Set 4 | ponta do sol
# Processing Record 13 of Set 4 | cotonou
# Processing Record 14 of Set 4 | teguldet
# Processing Record 15 of Set 4 | port alfred
# Processing Record 16 of Set 4 | hermanus
# Processing Record 17 of Set 4 | areia branca
# Processing Record 18 of Set 4 | ayan
# Processing Record 19 of Set 4 | norman wells
# Processing Record 20 of Set 4 | beringovskiy
# Processing Record 21 of Set 4 | port-gentil
# Processing Record 22 of Set 4 | georgetown
# Processing Record 23 of Set 4 | raudeberg
# Processing Record 24 of Set 4 | payo
# Processing Record 25 of Set 4 | cravo norte
# kuala krai not found. Skipping....
# Processing Record 26 of Set 4 | angoram
# Processing Record 27 of Set 4 | labuhan
# Processing Record 28 of Set 4 | saint pete beach
# Processing Record 29 of Set 4 | mango
# Processing Record 30 of Set 4 | murdochville
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | yellowknife
# Processing Record 33 of Set 4 | vao
# Processing Record 34 of Set 4 | cayenne
# Processing Record 35 of Set 4 | san patricio
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | shache
# Processing Record 38 of Set 4 | leningradskiy
# Processing Record 39 of Set 4 | kaeo
# Processing Record 40 of Set 4 | klaksvik
# tarudant not found. Skipping....
# Processing Record 41 of Set 4 | the pas
# tsihombe not found. Skipping....
# Processing Record 42 of Set 4 | plettenberg bay
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | bahia honda
# Processing Record 0 of Set 5 | islamkot
# Processing Record 1 of Set 5 | salo
# Processing Record 2 of Set 5 | coahuayana
# Processing Record 3 of Set 5 | melendugno
# Processing Record 4 of Set 5 | new norfolk
# Processing Record 5 of Set 5 | giyani
# mys shmidta not found. Skipping....
# Processing Record 6 of Set 5 | muravlenko
# Processing Record 7 of Set 5 | kitimat
# kamenskoye not found. Skipping....
# Processing Record 8 of Set 5 | dingle
# Processing Record 9 of Set 5 | esperance
# Processing Record 10 of Set 5 | nome
# Processing Record 11 of Set 5 | katsuura
# Processing Record 12 of Set 5 | axim
# Processing Record 13 of Set 5 | nata
# Processing Record 14 of Set 5 | great yarmouth
# Processing Record 15 of Set 5 | lieksa
# lugovskiy not found. Skipping....
# Processing Record 16 of Set 5 | westport
# Processing Record 17 of Set 5 | bonavista
# Processing Record 18 of Set 5 | solnechnyy
# Processing Record 19 of Set 5 | uvarovo
# Processing Record 20 of Set 5 | gamboma
# taburi not found. Skipping....
# Processing Record 21 of Set 5 | jijiang
# Processing Record 22 of Set 5 | aksarka
# Processing Record 23 of Set 5 | chuy
# Processing Record 24 of Set 5 | pringsewu
# Processing Record 25 of Set 5 | whitehorse
# Processing Record 26 of Set 5 | alofi
# Processing Record 27 of Set 5 | severo-kurilsk
# Processing Record 28 of Set 5 | hualmay
# Processing Record 29 of Set 5 | pisco
# Processing Record 30 of Set 5 | clyde river
# Processing Record 31 of Set 5 | lavrentiya
# Processing Record 32 of Set 5 | boa vista
# Processing Record 33 of Set 5 | flinders
# Processing Record 34 of Set 5 | srandakan
# paradwip not found. Skipping....
# Processing Record 35 of Set 5 | carutapera
# Processing Record 36 of Set 5 | bilibino
# Processing Record 37 of Set 5 | khasan
# piyi not found. Skipping....
# barentsburg not found. Skipping....
# Processing Record 38 of Set 5 | pangnirtung
# Processing Record 39 of Set 5 | riyadh
# Processing Record 40 of Set 5 | husavik
# Processing Record 41 of Set 5 | turbat
# Processing Record 42 of Set 5 | sao joao da barra
# Processing Record 0 of Set 6 | havoysund
# Processing Record 1 of Set 6 | gonbad-e qabus
# Processing Record 2 of Set 6 | sola
# artyk not found. Skipping....
# skalistyy not found. Skipping....
# Processing Record 3 of Set 6 | cam ranh
# Processing Record 4 of Set 6 | rio grande
# Processing Record 5 of Set 6 | flin flon
# Processing Record 6 of Set 6 | carauari
# Processing Record 7 of Set 6 | nichinan
# Processing Record 8 of Set 6 | pijino
# Processing Record 9 of Set 6 | manhush
# Processing Record 10 of Set 6 | pemba
# Processing Record 11 of Set 6 | mareeba
# Processing Record 12 of Set 6 | lubango
# Processing Record 13 of Set 6 | sabang
# Processing Record 14 of Set 6 | andenes
# Processing Record 15 of Set 6 | fortuna
# Processing Record 16 of Set 6 | havelock
# Processing Record 17 of Set 6 | merauke
# Processing Record 18 of Set 6 | santa rosa
# Processing Record 19 of Set 6 | cap-aux-meules
# Processing Record 20 of Set 6 | naze
# Processing Record 21 of Set 6 | yar-sale
# Processing Record 22 of Set 6 | aviles
# Processing Record 23 of Set 6 | thompson
# Processing Record 24 of Set 6 | urumqi
# brahmapuri not found. Skipping....
# Processing Record 25 of Set 6 | saint-philippe
# Processing Record 26 of Set 6 | touros
# Processing Record 27 of Set 6 | morgan city
# Processing Record 28 of Set 6 | yeniseysk
# Processing Record 29 of Set 6 | sal rei
# Processing Record 30 of Set 6 | kavieng
# Processing Record 31 of Set 6 | bethel
# ruatoria not found. Skipping....
# Processing Record 32 of Set 6 | codrington
# Processing Record 33 of Set 6 | richards bay
# Processing Record 34 of Set 6 | oromocto
# Processing Record 35 of Set 6 | saint anthony
# Processing Record 36 of Set 6 | fayetteville
# amderma not found. Skipping....
# Processing Record 37 of Set 6 | praya
# Processing Record 38 of Set 6 | mbanza-ngungu
# Processing Record 39 of Set 6 | port hedland
# Processing Record 40 of Set 6 | sioux lookout
# Processing Record 41 of Set 6 | bela
# Processing Record 42 of Set 6 | antofagasta
# Processing Record 43 of Set 6 | songjianghe
# satitoa not found. Skipping....
# tumannyy not found. Skipping....
# Processing Record 0 of Set 7 | altamira
# Processing Record 1 of Set 7 | noumea
# Processing Record 2 of Set 7 | yumen
# Processing Record 3 of Set 7 | dikson
# Processing Record 4 of Set 7 | goderich
# Processing Record 5 of Set 7 | alice springs
# Processing Record 6 of Set 7 | cap malheureux
# Processing Record 7 of Set 7 | bathsheba
# Processing Record 8 of Set 7 | warri
# Processing Record 9 of Set 7 | isangel
# Processing Record 10 of Set 7 | borzya
# Processing Record 11 of Set 7 | mulege
# Processing Record 12 of Set 7 | palmer
# Processing Record 13 of Set 7 | bethanien
# Processing Record 14 of Set 7 | cacequi
# Processing Record 15 of Set 7 | talnakh
# Processing Record 16 of Set 7 | tiksi
# Processing Record 17 of Set 7 | tornio
# Processing Record 18 of Set 7 | abu dhabi
# Processing Record 19 of Set 7 | tessalit
# Processing Record 20 of Set 7 | kindu
# Processing Record 21 of Set 7 | kruisfontein
# Processing Record 22 of Set 7 | kayes
# Processing Record 23 of Set 7 | havre-saint-pierre
# Processing Record 24 of Set 7 | cidreira
# Processing Record 25 of Set 7 | puerto escondido
# Processing Record 26 of Set 7 | stornoway
# Processing Record 27 of Set 7 | el triunfo
# Processing Record 28 of Set 7 | rio gallegos
# Processing Record 29 of Set 7 | olavarria
# Processing Record 30 of Set 7 | puerto colombia
# Processing Record 31 of Set 7 | quzhou
# karauzyak not found. Skipping....
# Processing Record 32 of Set 7 | makakilo city
# Processing Record 33 of Set 7 | lodja
# Processing Record 34 of Set 7 | swan hill
# Processing Record 35 of Set 7 | coihaique
# Processing Record 36 of Set 7 | truro
# barawe not found. Skipping....
# Processing Record 37 of Set 7 | north bend
# Processing Record 38 of Set 7 | bubaque
# Processing Record 39 of Set 7 | bairiki
# Processing Record 40 of Set 7 | atbasar
# Processing Record 41 of Set 7 | twentynine palms
# Processing Record 42 of Set 7 | kourou
# Processing Record 43 of Set 7 | brindisi
# Processing Record 44 of Set 7 | balkhash
# Processing Record 45 of Set 7 | knyaze-volkonskoye
# Processing Record 46 of Set 7 | grindavik
# Processing Record 0 of Set 8 | olenegorsk
# Processing Record 1 of Set 8 | ucluelet
# Processing Record 2 of Set 8 | pampas
# Processing Record 3 of Set 8 | adrar
# Processing Record 4 of Set 8 | guerrero negro
# grand river south east not found. Skipping....
# Processing Record 5 of Set 8 | coquimbo
# Processing Record 6 of Set 8 | ahualulco
# Processing Record 7 of Set 8 | tamandare
# chameza not found. Skipping....
# Processing Record 8 of Set 8 | bolshaya rechka
# Processing Record 9 of Set 8 | durango
# Processing Record 10 of Set 8 | hay river
# Processing Record 11 of Set 8 | buala
# Processing Record 12 of Set 8 | krasnoselkup
# Processing Record 13 of Set 8 | strezhevoy
# Processing Record 14 of Set 8 | khatanga
# Processing Record 15 of Set 8 | killybegs
# Processing Record 16 of Set 8 | caconda
# attawapiskat not found. Skipping....
# Processing Record 17 of Set 8 | churapcha
# Processing Record 18 of Set 8 | vestmannaeyjar
# Processing Record 19 of Set 8 | kamiiso
# Processing Record 20 of Set 8 | roebourne
# Processing Record 21 of Set 8 | longyan
# Processing Record 22 of Set 8 | santa luzia
# Processing Record 23 of Set 8 | olafsvik
# Processing Record 24 of Set 8 | champerico
# Processing Record 25 of Set 8 | nikolskoye
# Processing Record 26 of Set 8 | bereda
# Processing Record 27 of Set 8 | west bay
# Processing Record 28 of Set 8 | sharkan
# Processing Record 29 of Set 8 | la asuncion
# Processing Record 30 of Set 8 | kirkland lake
# Processing Record 31 of Set 8 | lingsugur
# Processing Record 32 of Set 8 | jacareacanga
# Processing Record 33 of Set 8 | hammerfest
# Processing Record 34 of Set 8 | geraldton
# braslav not found. Skipping....
# Processing Record 35 of Set 8 | dzaoudzi
# Processing Record 36 of Set 8 | itacarambi
# Processing Record 37 of Set 8 | homer
# Processing Record 38 of Set 8 | henties bay
# Processing Record 39 of Set 8 | metro
# Processing Record 40 of Set 8 | grand-lahou
# Processing Record 41 of Set 8 | channel-port aux basques
# Processing Record 42 of Set 8 | marawi
# Processing Record 43 of Set 8 | ahipara
# Processing Record 44 of Set 8 | hwange
# Processing Record 45 of Set 8 | gonen
# Processing Record 0 of Set 9 | luena
# Processing Record 1 of Set 9 | zhezkazgan
# Processing Record 2 of Set 9 | lipin bor
# Processing Record 3 of Set 9 | dudinka
# Processing Record 4 of Set 9 | garowe
# Processing Record 5 of Set 9 | kibaya
# Processing Record 6 of Set 9 | shirvan
# Processing Record 7 of Set 9 | evensk
# aflu not found. Skipping....
# Processing Record 8 of Set 9 | deloraine
# Processing Record 9 of Set 9 | lincoln
# Processing Record 10 of Set 9 | najran
# Processing Record 11 of Set 9 | castelfiorentino
# Processing Record 12 of Set 9 | gazimurskiy zavod
# Processing Record 13 of Set 9 | maxixe
# Processing Record 14 of Set 9 | oum hadjer
# Processing Record 15 of Set 9 | teutonia
# Processing Record 16 of Set 9 | nokaneng
# Processing Record 17 of Set 9 | beloha
# Processing Record 18 of Set 9 | caluquembe
# Processing Record 19 of Set 9 | okulovka
# Processing Record 20 of Set 9 | buzmeyin
# Processing Record 21 of Set 9 | kavaratti
# tabialan not found. Skipping....
# Processing Record 22 of Set 9 | mackenzie
# Processing Record 23 of Set 9 | shenzhen
# Processing Record 24 of Set 9 | baykit
# Processing Record 25 of Set 9 | hambantota
# Processing Record 26 of Set 9 | wajir
# Processing Record 27 of Set 9 | asau
# Processing Record 28 of Set 9 | muyezerskiy
# Processing Record 29 of Set 9 | bomi
# Processing Record 30 of Set 9 | igarka
# Processing Record 31 of Set 9 | skibbereen
# tabiauea not found. Skipping....
# Processing Record 32 of Set 9 | tsabong
# Processing Record 33 of Set 9 | meadow lake
# Processing Record 34 of Set 9 | ilulissat
# kuche not found. Skipping....
# Processing Record 35 of Set 9 | katima mulilo
# Processing Record 36 of Set 9 | mungwi
# Processing Record 37 of Set 9 | mount gambier
# Processing Record 38 of Set 9 | santa maria
# Processing Record 39 of Set 9 | nyimba
# Processing Record 40 of Set 9 | denpasar
# Processing Record 41 of Set 9 | prudentopolis
# Processing Record 42 of Set 9 | rapid city
# Processing Record 43 of Set 9 | caraballeda
# Processing Record 44 of Set 9 | rosarito
# Processing Record 45 of Set 9 | broken hill
# saleaula not found. Skipping....
# Processing Record 0 of Set 10 | navrongo
# Processing Record 1 of Set 10 | joutseno
# Processing Record 2 of Set 10 | ruteng
# Processing Record 3 of Set 10 | praia
# ust-bolsheretsk not found. Skipping....
# Processing Record 4 of Set 10 | laguna
# Processing Record 5 of Set 10 | marigot
# Processing Record 6 of Set 10 | chumikan
# Processing Record 7 of Set 10 | cabedelo
# Processing Record 8 of Set 10 | may pen
# Processing Record 9 of Set 10 | ambato
# Processing Record 10 of Set 10 | chillan
# Processing Record 11 of Set 10 | estelle
# malwan not found. Skipping....
# Processing Record 12 of Set 10 | ancud
# Processing Record 13 of Set 10 | lasa
# Processing Record 14 of Set 10 | mehamn
# Processing Record 15 of Set 10 | sohag
# Processing Record 16 of Set 10 | aykhal
# Processing Record 17 of Set 10 | kimbe
# orgun not found. Skipping....
# Processing Record 18 of Set 10 | vardo
# Processing Record 19 of Set 10 | parkes
# Processing Record 20 of Set 10 | port shepstone
# Processing Record 21 of Set 10 | marienburg
# Processing Record 22 of Set 10 | pachino
# Processing Record 23 of Set 10 | manama
# Processing Record 24 of Set 10 | robertsport
# Processing Record 25 of Set 10 | danielskuil
# Processing Record 26 of Set 10 | funadhoo
# Processing Record 27 of Set 10 | tarbes
# Processing Record 28 of Set 10 | matagami
# Processing Record 29 of Set 10 | harnosand
# Processing Record 30 of Set 10 | shiyan
# Processing Record 31 of Set 10 | souillac
# Processing Record 32 of Set 10 | vila velha
# Processing Record 33 of Set 10 | kingsland
# Processing Record 34 of Set 10 | taltal
# Processing Record 35 of Set 10 | korla
# Processing Record 36 of Set 10 | kabalo
# Processing Record 37 of Set 10 | panguna
# Processing Record 38 of Set 10 | liverpool
# Processing Record 39 of Set 10 | acapulco
# Processing Record 40 of Set 10 | walvis bay
# Processing Record 41 of Set 10 | galveston
# armacao dos buzios not found. Skipping....
# Processing Record 42 of Set 10 | xinyu
# Processing Record 43 of Set 10 | guiyang
# Processing Record 44 of Set 10 | muros
# Processing Record 0 of Set 11 | upington
# Processing Record 1 of Set 11 | hasaki
# Processing Record 2 of Set 11 | samarai
# Processing Record 3 of Set 11 | kurumkan
# Processing Record 4 of Set 11 | young
# andevoranto not found. Skipping....
# halalo not found. Skipping....
# Processing Record 5 of Set 11 | iqaluit
# Processing Record 6 of Set 11 | nouadhibou
# Processing Record 7 of Set 11 | okha
# Processing Record 8 of Set 11 | tarko-sale
# Processing Record 9 of Set 11 | srednekolymsk
# Processing Record 10 of Set 11 | saint-joseph
# Processing Record 11 of Set 11 | bonthe
# Processing Record 12 of Set 11 | bangassou
# Processing Record 13 of Set 11 | ampanihy
# barbar not found. Skipping....
# Processing Record 14 of Set 11 | atar
# Processing Record 15 of Set 11 | daloa
# Processing Record 16 of Set 11 | pangody
# Processing Record 17 of Set 11 | zhangjiakou
# Processing Record 18 of Set 11 | guilin
# Processing Record 19 of Set 11 | kijang
# Processing Record 20 of Set 11 | hohhot
# Processing Record 21 of Set 11 | yushala
# Processing Record 22 of Set 11 | dalton
# Processing Record 23 of Set 11 | ouesso
# Processing Record 24 of Set 11 | trinidad
# Processing Record 25 of Set 11 | sapouy
# Processing Record 26 of Set 11 | lahaina
# Processing Record 27 of Set 11 | neuquen
# Processing Record 28 of Set 11 | puerto madryn
# Processing Record 29 of Set 11 | benin
# Processing Record 30 of Set 11 | fergus falls
# Processing Record 31 of Set 11 | minot
# Processing Record 32 of Set 11 | san lawrenz
# Processing Record 33 of Set 11 | iquique
# Processing Record 34 of Set 11 | ozinki
# Processing Record 35 of Set 11 | puerto narino
# Processing Record 36 of Set 11 | takoradi
# Processing Record 37 of Set 11 | phra phutthabat
# Processing Record 38 of Set 11 | tautira
# Processing Record 39 of Set 11 | arona
# Processing Record 40 of Set 11 | haukipudas
# Processing Record 41 of Set 11 | charters towers
# labutta not found. Skipping....
# Processing Record 42 of Set 11 | khovu-aksy
# Processing Record 43 of Set 11 | vicuna
# Processing Record 44 of Set 11 | quatre cocos
# Processing Record 45 of Set 11 | wahiawa
# Processing Record 0 of Set 12 | virovitica
# Processing Record 1 of Set 12 | chimbote
# Processing Record 2 of Set 12 | talladega
# Processing Record 3 of Set 12 | port macquarie
# Processing Record 4 of Set 12 | turayf
# Processing Record 5 of Set 12 | bangui
# Processing Record 6 of Set 12 | la ronge
# Processing Record 7 of Set 12 | mlowo
# Processing Record 8 of Set 12 | andra
# Processing Record 9 of Set 12 | la tuque
# Processing Record 10 of Set 12 | maan
# Processing Record 11 of Set 12 | ende
# Processing Record 12 of Set 12 | rudnogorsk
# Processing Record 13 of Set 12 | methala
# Processing Record 14 of Set 12 | stettler
# bolungarvik not found. Skipping....
# Processing Record 15 of Set 12 | mirnyy
# Processing Record 16 of Set 12 | cumberland
# Processing Record 17 of Set 12 | along
# Processing Record 18 of Set 12 | cuamba
# Processing Record 19 of Set 12 | san pedro
# Processing Record 20 of Set 12 | chastyye
# Processing Record 21 of Set 12 | tabas
# Processing Record 22 of Set 12 | pasighat
# Processing Record 23 of Set 12 | pierre
# Processing Record 24 of Set 12 | vallenar
# Processing Record 25 of Set 12 | kribi
# Processing Record 26 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 12 | oyama
# Processing Record 28 of Set 12 | aripuana
# Processing Record 29 of Set 12 | sao sebastiao
# Processing Record 30 of Set 12 | penzance
# Processing Record 31 of Set 12 | lichtenburg
# Processing Record 32 of Set 12 | fare
# Processing Record 33 of Set 12 | broome
# Processing Record 34 of Set 12 | mocorito
# Processing Record 35 of Set 12 | launceston
# Processing Record 36 of Set 12 | saint-pierre
# marcona not found. Skipping....
# Processing Record 37 of Set 12 | nenjiang
# Processing Record 38 of Set 12 | bonnyville
# Processing Record 39 of Set 12 | karratha
# mrirt not found. Skipping....
# Processing Record 40 of Set 12 | kuruman
# Processing Record 41 of Set 12 | omboue
# Processing Record 42 of Set 12 | beira
# Processing Record 43 of Set 12 | bengkulu
# Processing Record 44 of Set 12 | dzilam gonzalez
# Processing Record 45 of Set 12 | camacha
# Processing Record 46 of Set 12 | mankono
# banmo not found. Skipping....
# Processing Record 0 of Set 13 | matara
# Processing Record 1 of Set 13 | bridlington
# Processing Record 2 of Set 13 | kikwit
# Processing Record 3 of Set 13 | khirkiya
# Processing Record 4 of Set 13 | dicabisagan
# Processing Record 5 of Set 13 | mwanza
# Processing Record 6 of Set 13 | berezovyy
# Processing Record 7 of Set 13 | pinega
# Processing Record 8 of Set 13 | yugo-kamskiy
# Processing Record 9 of Set 13 | pyaozerskiy
# Processing Record 10 of Set 13 | ushi
# vreed en hoop not found. Skipping....
# Processing Record 11 of Set 13 | verkhovye
# Processing Record 12 of Set 13 | kununurra
# Processing Record 13 of Set 13 | yanam
# ye not found. Skipping....
# Processing Record 14 of Set 13 | dire dawa
# Processing Record 15 of Set 13 | tanete
# Processing Record 16 of Set 13 | catamayo
# Processing Record 17 of Set 13 | ugoofaaru
# Processing Record 18 of Set 13 | kutum
# Processing Record 19 of Set 13 | san roque
# Processing Record 20 of Set 13 | ust-kulom
# Processing Record 21 of Set 13 | maragheh
# Processing Record 22 of Set 13 | fasa
# Processing Record 23 of Set 13 | moroni
# Processing Record 24 of Set 13 | salalah
# Processing Record 25 of Set 13 | macusani
# Processing Record 26 of Set 13 | tete
# Processing Record 27 of Set 13 | fort saint james
# Processing Record 28 of Set 13 | athabasca
# Processing Record 29 of Set 13 | fort stewart
# Processing Record 30 of Set 13 | diffa
# balimo not found. Skipping....
# Processing Record 31 of Set 13 | novobirilyussy
# Processing Record 32 of Set 13 | kirkwall
# meyungs not found. Skipping....
# Processing Record 33 of Set 13 | huarmey
# Processing Record 34 of Set 13 | gat
# Processing Record 35 of Set 13 | marsabit
# Processing Record 36 of Set 13 | katherine
# Processing Record 37 of Set 13 | the valley
# Processing Record 38 of Set 13 | anadyr

# %%
weather = {'City': cityname , 	'Lat' : Lat , 	'Lng' :Long	,'Max Temp':temp , 
           'Humidity' :Humidity , 	'Cloudiness':Clouds , 'Wind Speed' : Speed,	'Country Date' : Date}
data = pd.DataFrame(weather)
data.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     caravelas -17.7125  -39.2481     71.64        92           0
# 1       yenagoa   4.9247    6.2642     73.17        91          81
# 2   provideniya  64.3833 -173.3000     50.11        81          90
# 3    bredasdorp -34.5322   20.0403     49.32        93         100
# 4  puerto ayora  -0.7393  -90.3518     72.55        93          75
#
#    Wind Speed  Country Date
# 0        4.52    1626745679
# 1        3.76    1626745779
# 2        8.95    1626745706
# 3        4.61    1626745625
# 4        5.01    1626745659

# %%
data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  583.000000  583.000000  583.000000  583.000000  583.000000  583.000000
# mean    19.294978   12.926087   68.995009   71.737564   54.703259    7.317358
# std     33.476199   88.136639   13.725033   19.206727   39.543826    5.562381
# min    -54.800000 -175.200000   36.300000   10.000000    0.000000    0.000000
# 25%     -8.801450  -65.269550   59.325000   62.000000   11.000000    3.375000
# 50%     21.346900   18.336800   71.040000   76.000000   62.000000    5.860000
# 75%     48.945600   83.728150   79.670000   86.000000   96.000000    9.945000
# max     78.218600  179.316700  104.140000  100.000000  100.000000   30.820000
#
#        Country Date
# count  5.830000e+02
# mean   1.626746e+09
# std    1.151694e+02
# min    1.626745e+09
# 25%    1.626746e+09
# 50%    1.626746e+09
# 75%    1.626746e+09
# max    1.626746e+09

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data.to_csv('weather_data.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
date = dt.date.today().strftime("%m/%d/%y")
plt.scatter(data['Lat'] , data['Max Temp'] , marker = 'o' , edgecolors = 'k' ,s = 20 , alpha = 0.75)
plt.title('citylatitude vs. Max Temperature ({})'.format(date))
plt.xlabel('Latitude')
plt.ylabel('Maxt Temperature')
# Out:
# Text(0, 0.5, 'Maxt Temperature')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
